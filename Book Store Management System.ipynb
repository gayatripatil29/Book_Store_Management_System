# %%
from tkinter import *
from tkinter import ttk # For Tree table
import tkinter.messagebox as MessageBox
import mysql.connector as mysql
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
from tkinter import Entry , messagebox , Text , END , Tk , Button , Label , StringVar , PhotoImage, Radiobutton
import tkinter.font as tkFont

# %%
def add_product():
    add_new_product_window=Tk()
    add_new_product_window.geometry('1000x850')
    add_new_product_window.title('Add New Product')
    add_new_product_window.configure(bg='white')
    label_main=Label(add_new_product_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    b_name_label=Label(add_new_product_window,text='Product Name',bg='white').pack()
    b_name_entry=Entry(add_new_product_window)
    b_name_entry.pack()
    b_author_label=Label(add_new_product_window,text='Author Name',bg='white').pack()
    b_author_entry=Entry(add_new_product_window)
    b_author_entry.pack()
    b_genre_label=Label(add_new_product_window,text='Genre',bg='white').pack()
    b_genre_entry=Entry(add_new_product_window)
    b_genre_entry.pack()
    b_cost_label=Label(add_new_product_window,text='Cost',bg='white').pack()
    b_cost_entry=Entry(add_new_product_window)
    b_cost_entry.pack()
    b_quantity_label=Label(add_new_product_window,text='Quantity',bg='white').pack()
    b_quantity_entry=Entry(add_new_product_window)
    b_quantity_entry.pack()
    
    def add_insert():
        if (b_name_entry.get()=='' or b_author_entry.get()=='' or b_genre_entry.get()=='' or b_cost_entry.get()=='' or b_quantity_entry.get()==''):
            MessageBox.showinfo('Please fill all the fields')
        else:
            now=datetime.now()
            MessageBox.showinfo('Book Name : {b_name_entry.get()} \n Author Name : {b_author_entry.get()} \n Genre : {b_genre_entry.get()} \n Cost : {b_cost_entry.get()} \n Quantity : {b_quantity_entry.get()}')
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='INSERT INTO purchased_list values (%s,%s,%s,%s,%s,%s)'
            val=(b_name_entry.get(),b_author_entry.get(),b_genre_entry.get(),b_cost_entry.get(),b_quantity_entry.get(),now)
            cursor.execute(sql,val)
            cursor.execute('commit')
            b_name_entry.delete(first=0,last='end')
            b_author_entry.delete(first=0,last='end')
            b_genre_entry.delete(first=0,last='end')
            b_cost_entry.delete(first=0,last='end')
            b_quantity_entry.delete(first=0,last='end')
            MessageBox.showinfo('Insert Status','Inserted Successfully')
            cursor.close()

    b_insert=Button(add_new_product_window,text='Add',command=add_insert,bg='deepskyblue3',fg='white')
    b_insert.pack()
    
    def close_program():
        add_new_product_window.destroy()
    button_exit=Button(add_new_product_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        add_new_product_window.destroy()
        admin_activities()
    button_back=Button(add_new_product_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    
    add_new_product_window.mainloop()

    
# --------------------------------------------------  Update Product  -----------------------------------------------------

def update_product():
    update_product_window=Tk()
    update_product_window.geometry('1000x850')
    update_product_window.title('Update Product Details')
    update_product_window.configure(bg='white')
    label_main=Label(update_product_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    u_id_label=Label(update_product_window,text='Enter Product ID',bg='white').pack()
    u_id_entry=Entry(update_product_window)
    u_id_entry.pack()
    u_name_label=Label(update_product_window,text='Name',bg='white').pack()
    u_name_entry=Entry(update_product_window)
    u_name_entry.pack()
    u_cost_label=Label(update_product_window,text='Author',bg='white').pack()
    u_cost_entry=Entry(update_product_window)
    u_cost_entry.pack()
    u_category_label=Label(update_product_window,text='Genre',bg='white').pack()
    u_category_entry=Entry(update_product_window)
    u_category_entry.pack()
    u_quantity_label=Label(update_product_window,text='Cost',bg='white').pack()
    u_quantity_entry=Entry(update_product_window)
    u_quantity_entry.pack()
    u_desc_label=Label(update_product_window,text='Quantity',bg='white').pack()
    u_desc_entry=Entry(update_product_window)
    u_desc_entry.pack()
    
    def update_submit():
        if (u_id_entry.get()=='' or u_name_entry.get()=='' or u_cost_entry.get()=='' or u_category_entry.get()=='' or u_quantity_entry.get()=='' or u_desc_entry.get()==''):
            MessageBox.showinfo('Please fill all the fields')
        else:
            MessageBox.showinfo('Book ID : {u_id_entry.get()} \n Book Name : {u_name_entry.get()} \n Author Name : {u_author_entry.get()} \n Genre : {u_genre_entry.get()} \n Cost : {u_cost_entry.get()} \n Quantity : {u_quantity_entry.get()}')  
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='UPDATE books_list set b_name=%s,b_author=%s,b_genre=%s,b_cost=%s,b_quantity=%s WHERE b_id=%s'
            val=(u_name_entry.get(),u_author_entry.get(),u_genre_entry.get(),u_cost_entry.get(),u_quantity_entry.get(),u_id_entry.get())
            cursor.execute(sql,val)
            cursor.execute('commit')
            u_id_entry.delete(0,'end')
            u_name_entry.delete(0,'end')
            u_author_entry.delete(0,'end')
            u_genre_entry.delete(0,'end')
            u_cost_entry.delete(0,'end')
            u_quantity_entry.delete(0,'end')
            MessageBox.showinfo('Update Status','Updated Successfully')
            cursor.close()
            
    u_submit=Button(update_product_window,text='SUBMIT',command=update_submit,bg='deepskyblue3',fg='white')
    u_submit.pack()
    
    def close_program():
        update_product_window.destroy()
    button_exit=Button(update_product_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    
    def back_program():
        update_product_window.destroy()
        admin_activities()
    button_back=Button(update_product_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    
    update_product_window.mainloop()

# --------------------------------------------------  Search Function  -----------------------------------------------------

def search_product():
    def filter_book():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT * FROM books_list WHERE b_name='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
    
    def filter_author():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT * FROM books_list WHERE b_author='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
                
    def filter_genre():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT * FROM books_list WHERE b_genre='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
                
    def choice() :
            choice = choice_admin.get()
            
            if choice == 1 :
                filter_book()
                
            if choice == 2 :
                filter_author()
            
            if choice == 3 :
                filter_genre()
                
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor=mydb.cursor()
    sql='SELECT * FROM books_list'
    cursor.execute(sql)
    row=cursor.fetchall()
    search_product_window=Tk()
    search_product_window.geometry('1000x850')
    search_product_window.title('Search Product')
    search_product_window.configure(bg='white')
    label_main=Label(search_product_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    all_product_label=Label(search_product_window,text='All Products Table',bg='white').pack()
    all_table=ttk.Treeview(search_product_window,columns=(1,2,3,4,5,6),show='headings',height='10')
    all_table.pack()
    all_table.heading(1,text='Book ID')
    all_table.column(1,width=60,stretch=NO)
    all_table.heading(2,text='Book Name')
    all_table.column(2,width=180,stretch=NO)
    all_table.heading(3,text='Author Name')
    all_table.column(3,width=180,stretch=NO)
    all_table.heading(4,text='Genre')
    all_table.column(4,width=180,stretch=NO)
    all_table.heading(5,text='Cost')
    all_table.column(5,width=180,stretch=NO)
    all_table.heading(6,text='Quantity')
    all_table.column(6,width=180,stretch=NO)
    for i in row:
        all_table.insert('','end',values=i)
    
    
    #radio_button 
    choice_admin = IntVar()
    search_label_1=Label(search_product_window,text='Filter Products by',font='20',bg='white').pack()
    radio_add    = Radiobutton(search_product_window , text = 'Book '   , value = 1 , variable = choice_admin,bg='white' ).pack()
    radio_delete = Radiobutton(search_product_window , text = 'Author', value = 2 , variable = choice_admin,bg='white' ).pack()
    radio_search = Radiobutton(search_product_window , text = 'Genre', value = 3 , variable = choice_admin,bg='white' ).pack()
        
    search_label_2=Label(search_product_window,text='Enter Field',font='20',bg='white').pack()
    filter_entry=Entry(search_product_window)
    filter_entry.pack()
    filter_button=Button(search_product_window,text='Filter',command=choice,bg='deepskyblue3',fg='white').pack()
    filter_product_label=Label(search_product_window,text='Filter Products Table',bg='white').pack()
    filter_table=ttk.Treeview(search_product_window,columns=(1,2,3,4,5,6),show='headings',height='10')
    filter_table.pack()
    filter_table.heading(1,text='Book ID')
    filter_table.column(1,width=60,stretch=NO)
    filter_table.heading(2,text='Book Name')
    filter_table.column(2,width=180,stretch=NO)
    filter_table.heading(3,text='Author Name')
    filter_table.column(3,width=180,stretch=NO)
    filter_table.heading(4,text='Genre')
    filter_table.column(4,width=180,stretch=NO)
    filter_table.heading(5,text='Cost')
    filter_table.column(5,width=180,stretch=NO)
    filter_table.heading(6,text='Quantity')
    filter_table.column(6,width=180,stretch=NO)
    
    def close_program():
        search_product_window.destroy()
    button_exit=Button(search_product_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        search_product_window.destroy()
        admin_activities()
    button_back=Button(search_product_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    search_product_window.mainloop()
# -----------------------------------------------------  Delete Product ----------------------------------------------------   

def delete_product():
    delete_product_window=Tk()
    delete_product_window.geometry('1000x850')
    delete_product_window.title('Delete Product')
    delete_product_window.configure(bg='white')
    label_main=Label(delete_product_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    delete_label_1=Label(delete_product_window,text='Delete Book',bg='white').pack()
    delete_label_2=Label(delete_product_window,text='Enter Book ID',bg='white').pack()
    delete_entry=Entry(delete_product_window)
    delete_entry.pack()
    
    def show_delete():
        if(delete_entry.get()==''):
            MessageBox.showinfo('Delete Status','All fields are required')
        else:
            delete_table.delete(*delete_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT*FROM books_list WHERE b_id='"+ delete_entry.get() +"'")
            delete_row=cursor.fetchall()
            for i in delete_row:
                delete_table.insert('','end',values=i)
                
    ok_button=Button(delete_product_window,text='OK',command=show_delete,bg='deepskyblue3',fg='white')
    ok_button.pack()
    delete_table=ttk.Treeview(delete_product_window,columns=(1,2,3,4,5,6),show='headings',height='1')
    delete_table.pack()
    delete_table.heading(1,text='Book ID')
    delete_table.column(1,width=60,stretch=NO)
    delete_table.heading(2,text='Book Name')
    delete_table.column(2,width=180,stretch=NO)
    delete_table.heading(3,text='Author Name')
    delete_table.column(3,width=180,stretch=NO)
    delete_table.heading(4,text='Genre')
    delete_table.column(4,width=180,stretch=NO)
    delete_table.heading(5,text='Cost')
    delete_table.column(5,width=180,stretch=NO)
    delete_table.heading(6,text='Quantity')
    delete_table.column(6,width=180,stretch=NO)
    
    
    def final_delete():
        delete_table.delete(*delete_table.get_children())
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor=mydb.cursor()
        cursor.execute("DELETE FROM books_list WHERE b_id='"+ delete_entry.get() +"'")
        cursor.execute('commit');
        MessageBox.showinfo('Delete Status','Deleted Successfully')
        cursor.close() 
        
    delete_button=Button(delete_product_window,text='DELETE',command=final_delete,bg='deepskyblue3',fg='white')
    delete_button.pack()
    
    def close_program():
        delete_product_window.destroy()
    button_exit=Button(delete_product_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        delete_product_window.destroy()
        admin_activities()
    button_back=Button(delete_product_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    delete_product_window.mainloop()
    
    
# ----------------------------------------------------  Customer Registration  -----------------------------------------------
def customer_registration():
    def sub_registration():
        print(first_name_entry.get(),last_name_entry.get(),email_name_entry.get(),phone_name_entry.get(),address_name_entry.get())
        if(first_name_entry.get()=='' or last_name_entry.get()=='' or email_name_entry.get()=='' or phone_name_entry.get()=='' or address_name_entry.get()==''):
            MessageBox.showinfo('Update Status','All fields are required')
        else:
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='INSERT INTO cust_registration(c_first_name,c_last_name,c_email,c_phone,c_address) values (%s,%s,%s,%s,%s)'
            val=(first_name_entry.get(),last_name_entry.get(),email_name_entry.get(),phone_name_entry.get(),address_name_entry.get())
            cursor.execute(sql,val)
            cursor.execute('commit')
            first_name_entry.delete(0,'end')
            last_name_entry.delete(0,'end')
            email_name_entry.delete(0,'end')
            phone_name_entry.delete(0,'end')
            address_name_entry.delete(0,'end')
            MessageBox.showinfo('Insert Status','Inserted Successfully')
            cursor.close()
            
    customer_registration_window=Tk()
    customer_registration_window.geometry('1000x850')
    customer_registration_window.configure(bg='white')
    customer_registration_window.title('Customer Registration')
    label_main=Label(customer_registration_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    label_customer=Label(customer_registration_window,text='Customer Registration',bg='white').pack()
    label_first_name=Label(customer_registration_window,text='First Name',bg='white').pack()
    first_name_entry=Entry(customer_registration_window)
    first_name_entry.pack()
    label_last_name=Label(customer_registration_window,text='Last Name',bg='white').pack()
    last_name_entry=Entry(customer_registration_window)
    last_name_entry.pack()
    label_email_name=Label(customer_registration_window,text='Email Address',bg='white').pack()
    email_name_entry=Entry(customer_registration_window)
    email_name_entry.pack()
    label_phone_name=Label(customer_registration_window,text='Phone Number',bg='white').pack()
    phone_name_entry=Entry(customer_registration_window)
    phone_name_entry.pack()
    label_address_name=Label(customer_registration_window,text='Address',bg='white').pack()
    address_name_entry=Entry(customer_registration_window)
    address_name_entry.pack()
    reg_sub_button=Button(customer_registration_window,text='SUBMIT',command=sub_registration,bg='deepskyblue3',fg='white')
    reg_sub_button.pack()
    
    def close_program():
        customer_registration_window.destroy()
    button_exit=Button(customer_registration_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        customer_registration_window.destroy()
        admin_activities()
    button_back=Button(customer_registration_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    customer_registration_window.mainloop()
    

# --------------------------------------------------  Update Product  -----------------------------------------------------

def update_customer():
    update_customer_window=Tk()
    update_customer_window.geometry('1000x850')
    update_customer_window.title('Update Customer Details')
    update_customer_window.configure(bg='white')
    label_main=Label(update_customer_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    u_id_label=Label(update_customer_window,text='Enter Customer ID',bg='white').pack()
    u_id_entry=Entry(update_customer_window)
    u_id_entry.pack()
    u_first_label=Label(update_customer_window,text='First Name',bg='white').pack()
    u_first_entry=Entry(update_customer_window)
    u_first_entry.pack()
    u_last_label=Label(update_customer_window,text='Last Name',bg='white').pack()
    u_last_entry=Entry(update_customer_window)
    u_last_entry.pack()
    u_email_label=Label(update_customer_window,text='Email Address',bg='white').pack()
    u_email_entry=Entry(update_customer_window)
    u_email_entry.pack()
    u_phone_label=Label(update_customer_window,text='Phone Number',bg='white').pack()
    u_phone_entry=Entry(update_customer_window)
    u_phone_entry.pack()
    u_address_label=Label(update_customer_window,text='Address',bg='white').pack()
    u_address_entry=Entry(update_customer_window)
    u_address_entry.pack()
    
    def update_submit():
        if (u_id_entry.get()=='' or u_first_entry.get()=='' or u_last_entry.get()=='' or u_email_entry.get()=='' or u_phone_entry.get()=='' or u_address_entry.get()==''):
            MessageBox.showinfo('Please fill all the fields')
        else:
            MessageBox.showinfo('Customer ID : {u_id_entry.get()} \n First Name : {u_first_entry.get()} \n Last Name : {u_last_entry.get()} \n Email ID : {u_email_entry.get()} \n Phone no. : {u_phone_entry.get()} \n Address : {u_address_entry.get()}')  
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='UPDATE cust_registration set c_first_name=%s,c_last_name=%s,c_email=%s,c_phone=%s,c_address=%s WHERE c_id=%s'
            val=(u_first_entry.get(),u_last_entry.get(),u_email_entry.get(),u_phone_entry.get(),u_address_entry.get(),u_id_entry.get())
            cursor.execute(sql,val)
            cursor.execute('commit')
            u_id_entry.delete(0,'end')
            u_first_entry.delete(0,'end')
            u_last_entry.delete(0,'end')
            u_email_entry.delete(0,'end')
            u_phone_entry.delete(0,'end')
            u_address_entry.delete(0,'end')
            MessageBox.showinfo('Update Status','Updated Successfully')
            cursor.close()
            
    u_submit=Button(update_customer_window,text='SUBMIT',command=update_submit,bg='deepskyblue3',fg='white')
    u_submit.pack()
    
    def close_program():
        update_customer_window.destroy()
    button_exit=Button(update_customer_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    
    def back_program():
        update_customer_window.destroy()
        admin_activities()
    button_back=Button(update_customer_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    
    update_customer_window.mainloop()

# --------------------------------------------------  Search Function  -----------------------------------------------------

def search_customer():
    def customer_id():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT * FROM cust_registration WHERE b_id='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
    
    def first_name():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT * FROM cust_registration WHERE c_first_name='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
                
    def last_name():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT * FROM cust_registration WHERE c_last_name='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
                
    def choice() :
            choice = choice_admin.get()
            
            if choice == 1 :
                customer_id()
                
            if choice == 2 :
                first_name()
            
            if choice == 3 :
                last_name()
                
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor=mydb.cursor()
    sql='SELECT * FROM cust_registration'
    cursor.execute(sql)
    row=cursor.fetchall()
    search_customer_window=Tk()
    search_customer_window.geometry('1000x850')
    search_customer_window.title('Search Customer')
    search_customer_window.configure(bg='white')
    label_main=Label(search_customer_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    all_product_label=Label(search_customer_window,text='All Customers Table',bg='white').pack()
    all_table=ttk.Treeview(search_customer_window,columns=(1,2,3,4,5,6),show='headings',height='10')
    all_table.pack()
    all_table.heading(1,text='Customer ID')
    all_table.column(1,width=60,stretch=NO)
    all_table.heading(2,text='First Name')
    all_table.column(2,width=180,stretch=NO)
    all_table.heading(3,text='Last Name')
    all_table.column(3,width=180,stretch=NO)
    all_table.heading(4,text='Email')
    all_table.column(4,width=180,stretch=NO)
    all_table.heading(5,text='Phone')
    all_table.column(5,width=180,stretch=NO)
    all_table.heading(6,text='Address')
    all_table.column(6,width=180,stretch=NO)
    for i in row:
        all_table.insert('','end',values=i)
    
    
    #radio_button 
    choice_admin = IntVar()
    search_label_1=Label(search_customer_window,text='Filter Customers by',font='20',bg='white').pack()
    radio_add    = Radiobutton(search_customer_window , text = 'Customer ID '   , value = 1 , variable = choice_admin,bg='white' ).pack()
    radio_delete = Radiobutton(search_customer_window , text = 'First Name', value = 2 , variable = choice_admin,bg='white' ).pack()
    radio_search = Radiobutton(search_customer_window , text = 'Last Name', value = 3 , variable = choice_admin,bg='white' ).pack()
        
    search_label_2=Label(search_customer_window,text='Enter Field',font='20',bg='white').pack()
    filter_entry=Entry(search_customer_window)
    filter_entry.pack()
    filter_button=Button(search_customer_window,text='Filter',command=choice,bg='deepskyblue3',fg='white').pack()
    filter_product_label=Label(search_customer_window,text='Filtered Customer Table',bg='white').pack()
    filter_table=ttk.Treeview(search_customer_window,columns=(1,2,3,4,5,6),show='headings',height='10')
    filter_table.pack()
    filter_table.heading(1,text='Customer ID')
    filter_table.column(1,width=60,stretch=NO)
    filter_table.heading(2,text='First Name')
    filter_table.column(2,width=180,stretch=NO)
    filter_table.heading(3,text='Last Name')
    filter_table.column(3,width=180,stretch=NO)
    filter_table.heading(4,text='Email')
    filter_table.column(4,width=180,stretch=NO)
    filter_table.heading(5,text='Phone')
    filter_table.column(5,width=180,stretch=NO)
    filter_table.heading(6,text='Address')
    filter_table.column(6,width=180,stretch=NO)
    
    def close_program():
        search_customer_window.destroy()
    button_exit=Button(search_customer_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        search_customer_window.destroy()
        admin_activities()
    button_back=Button(search_customer_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    search_customer_window.mainloop()
    
    

# -----------------------------------------------------  Delete Customer ----------------------------------------------------   

def delete_customer():
    delete_customer_window=Tk()
    delete_customer_window.geometry('1000x850')
    delete_customer_window.title('Delete Customer')
    delete_customer_window.configure(bg='white')
    label_main=Label(delete_customer_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    delete_label_1=Label(delete_customer_window,text='Delete Customer',bg='white').pack()
    delete_label_2=Label(delete_customer_window,text='Enter Customer ID',bg='white').pack()
    delete_entry=Entry(delete_customer_window)
    delete_entry.pack()
    
    def show_delete():
        if(delete_entry.get()==''):
            MessageBox.showinfo('Delete Status','All fields are required')
        else:
            delete_table.delete(*delete_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT*FROM cust_registration WHERE c_id='"+ delete_entry.get() +"'")
            delete_row=cursor.fetchall()
            for i in delete_row:
                delete_table.insert('','end',values=i)
                
    ok_button=Button(delete_customer_window,text='OK',command=show_delete,bg='deepskyblue3',fg='white')
    ok_button.pack()
    delete_table=ttk.Treeview(delete_customer_window,columns=(1,2,3,4,5,6),show='headings',height='1')
    delete_table.pack()
    delete_table.heading(1,text='Book ID')
    delete_table.heading(2,text='Book Name')
    delete_table.heading(3,text='Author Name')
    delete_table.heading(4,text='Genre')
    delete_table.heading(5,text='Cost')
    delete_table.heading(6,text='Quantity')
    
    
    def final_delete():
        delete_table.delete(*delete_table.get_children())
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='sql_project')
        cursor=mydb.cursor()
        cursor.execute("DELETE FROM cust_registration WHERE c_id='"+ delete_entry.get() +"'")
        cursor.execute('commit');
        MessageBox.showinfo('Delete Status','Deleted Successfully')
        cursor.close() 
        
    delete_button=Button(delete_customer_window,text='DELETE',command=final_delete,bg='deepskyblue3',fg='white')
    delete_button.pack()
    
    def close_program():
        delete_customer_window.destroy()
    button_exit=Button(delete_customer_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        delete_customer_window.destroy()
        admin_activities()
    button_back=Button(delete_customer_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    delete_customer_window.mainloop()
    

    
# ----------------------------------------------------  Customer Buy Products  -----------------------------------------------
# p_id,p_name,p_cost,p_category,p_description
def sale_products():
    invoice_product_list=[]
    invoice_sale_list=[]
    invoice_quantity_list=[]
    def generate_invoice():
        def payment_done():
            #print('Payment Done Succesfully !!!')
            for m in range(len(invoice_product_list)):
                mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
                cursor=mydb.cursor()
                sql='UPDATE books_list set b_quantity=b_quantity-%s WHERE b_id=%s'
                val=(invoice_quantity_list[m],invoice_product_list[m])
                cursor.execute(sql,val)
                cursor.execute('commit')
                print('Done !!')
                cursor.close()
            for n in range(len(invoice_product_list)):
                current_time = datetime.now()
                mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='sql_project')
                cursor=mydb.cursor()
                sql='INSERT INTO sales_details(cust_id,b_id,b_quantity,b_sales_amount,cust_time) values (%s,%s,%s,%s,%s)'
                val=(cust_id_entry.get(),invoice_product_list[n],invoice_quantity_list[n],invoice_quantity_list[n]*invoice_sale_list[n],current_time)
                cursor.execute(sql,val)
                cursor.execute('commit')
                print('Done !!')
                cursor.close()
            MessageBox.showinfo('Updated Status','Updated Successfully')   
            generate_invoice.destroy()    
        invoice_final_list=[]
        grand_total=0
        generate_invoice=Tk()
        generate_invoice.geometry('1000x850')
        label_main=Label(generate_invoice,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
        label_show_all_products=Label(generate_invoice,text='INVOICE',bg='white').pack()
        invoice_table=ttk.Treeview(generate_invoice,columns=(1,2,3,4,5),show='headings',height='10')
        invoice_table.pack()
        invoice_table.heading(1,text='Book ID')
        invoice_table.heading(2,text='Book Name')
        invoice_table.heading(3,text='Cost')
        invoice_table.heading(4,text='Quantity')
        invoice_table.heading(5,text='Total')
    #  ------------------------------------------------------------------------------------------------------------------------    
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        for i in range(len(invoice_product_list)):
            invoice_temp=[]
            cursor_invoice=mydb.cursor() # To get all products
            cursor_invoice.execute("SELECT b_id,b_name,b_cost FROM books_list WHERE b_id='"+ str(invoice_product_list[i]) +"'")
            invoice_row=cursor_invoice.fetchall()
            for l in range(3):
                invoice_temp.append(invoice_row[0][l])
            invoice_temp.append(invoice_quantity_list[i])
            invoice_temp.append(invoice_temp[2]*invoice_temp[3])
            invoice_final_list.append(tuple(invoice_temp))
        for j in invoice_final_list:
            invoice_table.insert('','end',values=j)
        for k in range(len(invoice_final_list)):
            grand_total=grand_total+invoice_final_list[k][4]
        print('Grand Total - ',grand_total)
        invoice_table.insert('','end',values=('------------------------------------','------------------------------------','------------------------------------','------------------------------------','------------------------------------'))
        invoice_table.insert('','end',values=('','','','Grand Total ----------------------->', grand_total))
       
        payment_done=Button(generate_invoice,text='PAYMENT DONE',bg='red',command=payment_done)
        payment_done.pack()
        
    #  ------------------------------------------------------------------------------------------------------------------------     
    def add_to_cart(): # To add products to cart
        cart_table_list=[]
        temp=[]
        
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor_cust_id=mydb.cursor() # To get all customer ids
        sql_all_products='SELECT c_id FROM cust_registration'
        cursor_cust_id.execute(sql_all_products)
        cust_ids=[c_id[0] for c_id in cursor_cust_id.fetchall()]
        
        cursor_prod_id=mydb.cursor() # To get all product ids
        sql_product_ids='SELECT b_id FROM purchased_list'
        cursor_prod_id.execute(sql_product_ids)
        prod_ids=[b_id[0] for b_id in cursor_prod_id.fetchall()]
        
        cursor_prod_quantity=mydb.cursor() # To get all product ids
        cursor_prod_quantity.execute("SELECT b_quantity FROM purchased_list where b_id='"+ cart_product_id_entry.get() +"' ")
        prod_quantity=prod_quantity=(cursor_prod_quantity.fetchall())[0][0]
        
        if((int(cust_id_entry.get()) in cust_ids) and (int(cart_product_id_entry.get()) in prod_ids) and ((prod_quantity-int(cart_product_quantity_entry.get()))>=0)):
            cursor_cart_table=mydb.cursor() # To get all product ids
            cursor_cart_table.execute("SELECT b_id,b_name,b_author,b_genre,b_cost,b_quantity FROM books_list where b_id='"+ cart_product_id_entry.get() +"' ")
            row_cart_table=cursor_cart_table.fetchall()
            for i in range(5):
                temp.append(row_cart_table[0][i])
            temp.append(int(cart_product_quantity_entry.get()))
            temp=tuple(temp)
            cart_table_list.append(temp)
            for i in cart_table_list:
                cart_table.insert('','end',values=i)
            invoice_product_list.append(temp[0])
            invoice_quantity_list.append(temp[5])
            invoice_sale_list.append(temp[4])
        else:
            MessageBox.showinfo('Insert Status','All fields are required or Quantity Null')
        
    
# -----------------------------------------------  To Display All Products  ----------------------------------------------------    
    
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor_all_product=mydb.cursor() # To get all products
    sql_all_products='SELECT * FROM books_list'
    cursor_all_product.execute(sql_all_products)
    row=cursor_all_product.fetchall()
    customer_buy_window=Tk()
    customer_buy_window.geometry('1000x850')
    customer_buy_window.configure(bg='white')
    customer_buy_window.title('Sell Products')
    label_main=Label(customer_buy_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    label_show_all_products=Label(customer_buy_window,text='All Products Table',bg='white').pack()
    all_table=ttk.Treeview(customer_buy_window,columns=(1,2,3,4,5,6),show='headings',height='10')
    all_table.pack()
    all_table.heading(1,text='Book ID')
    all_table.column(1,width=60,stretch=NO)
    all_table.heading(2,text='Book Name')
    all_table.column(2,width=180,stretch=NO)
    all_table.heading(3,text='Author Name')
    all_table.column(3,width=180,stretch=NO)
    all_table.heading(4,text='Genre')
    all_table.column(4,width=140,stretch=NO)
    all_table.heading(5,text='Cost')
    all_table.column(5,width=140,stretch=NO)
    all_table.heading(6,text='Quantity')
    all_table.column(6,width=140,stretch=NO)
    for i in row:
        all_table.insert('','end',values=i)
    
    label_cust_id=Label(customer_buy_window,text='Enter Customer ID ',bg='white').pack()
    cust_id_entry=Entry(customer_buy_window)
    cust_id_entry.pack()
    cart_product_id=Label(customer_buy_window,text='Enter the Product ID to Add to Cart',bg='white').pack()
    cart_product_id_entry=Entry(customer_buy_window)
    cart_product_id_entry.pack()
    cart_product_id=Label(customer_buy_window,text='Enter Quantity',bg='white').pack()
    cart_product_quantity_entry=Entry(customer_buy_window)
    cart_product_quantity_entry.pack()
    cart_product_add_button=Button(customer_buy_window,text='ADD TO CART',command=add_to_cart,bg='deepskyblue3',fg='white')
    cart_product_add_button.pack()
    cart_table=ttk.Treeview(customer_buy_window,columns=(1,2,3,4,5,6),show='headings',height='5')
    cart_table.pack()
    cart_table.heading(1,text='Book ID')
    cart_table.column(1,width=60,stretch=NO)
    cart_table.heading(2,text='Book Name')
    cart_table.column(2,width=180,stretch=NO)
    cart_table.heading(3,text='Author Name')
    cart_table.column(3,width=180,stretch=NO)
    cart_table.heading(4,text='Genre')
    cart_table.column(4,width=140,stretch=NO)
    cart_table.heading(5,text='Cost')
    cart_table.column(5,width=140,stretch=NO)
    cart_table.heading(6,text='Qty Sold')
    cart_table.column(6,width=140,stretch=NO)
    invoice_button=Button(customer_buy_window,text='GENERATE INVOICE',bg='red',command=generate_invoice)
    invoice_button.pack()
    
    def close_program():
        customer_buy_window.destroy()
    button_exit=Button(customer_buy_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        customer_buy_window.destroy()
        admin_activities()
    button_back=Button(customer_buy_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    customer_buy_window.mainloop()


# ----------------------------------------------------  Sales Report  -----------------------------------------------

def sales_report():
    def generate_rep():
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor=mydb.cursor()
        sql='select cust_id,b_id,date(cust_time),b_quantity,b_sales_amount into outfile "C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sales_report.csv" fields terminated by "," optionally enclosed by "" lines terminated by "\n" from sales_details;'
        cursor.execute(sql)
        cursor.execute('commit')
    
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor=mydb.cursor()
    sql='SELECT cust_id,b_id,date(cust_time),b_quantity,b_sales_amount FROM sales_details'
    cursor.execute(sql)
    row=cursor.fetchall()
    sales_window=Tk()
    sales_window.geometry('1000x850')
    sales_window.title('Search Product')
    sales_window.configure(bg='white')
    label_main=Label(sales_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    all_product_label=Label(sales_window,text='Sales Details',bg='white').pack()
    all_table=ttk.Treeview(sales_window,columns=(1,2,3,4,5),show='headings',height='10')
    all_table.pack()
    all_table.heading(1,text='Customer ID')
    all_table.column(1,width=180,stretch=NO)
    all_table.heading(2,text='Book ID')
    all_table.column(2,width=180,stretch=NO)
    all_table.heading(3,text='Date')
    all_table.column(3,width=180,stretch=NO)
    all_table.heading(4,text='Qty Sold')
    all_table.column(4,width=180,stretch=NO)
    all_table.heading(5,text='Total Amount')
    all_table.column(5,width=180,stretch=NO)
    for i in row:
        all_table.insert('','end',values=i)
        
    button=Button(sales_window,text='Generate Report',command=generate_rep,bg='deepskyblue3',fg='white').pack()
    def close_program():
        sales_window.destroy()
    button_exit=Button(sales_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        sales_window.destroy()
        admin_activities()
    button_back=Button(sales_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    sales_window.mainloop()
    
    
    
    
# ----------------------------------------------------  Productwise Sales Report  -----------------------------------------------

def sales_productwise_rep():
    def filter_product():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT cust_id,b_id,date(cust_time),b_quantity,b_sales_amount FROM sales_details WHERE b_id='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
                
    def generate_rep(b_id):
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor=mydb.cursor()
        sql=f'select cust_id,b_id,date(cust_time),b_quantity,b_sales_amount where b_id={b_id} into outfile "C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sales_report.csv" fields terminated by "," optionally enclosed by "" lines terminated by "\n" from sales_details;'
        cursor.execute(sql)
        cursor.execute('commit')
    
    
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor=mydb.cursor()
    sql='SELECT cust_id,b_id,date(cust_time),b_quantity,b_sales_amount FROM sales_details'
    cursor.execute(sql)
    row=cursor.fetchall()
    product_history_window=Tk()
    product_history_window.geometry('1000x850')
    product_history_window.configure(bg='white')
    product_history_window.title('Productwise Sales Report')
    label_main=Label(product_history_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    all_product_label=Label(product_history_window,text='Productwise Sales Report',bg='white').pack()
    all_table=ttk.Treeview(product_history_window,columns=(1,2,3,4,5),show='headings',height='10')
    all_table.pack()
    all_table.heading(1,text='Customer ID')
    all_table.heading(2,text='Book ID')
    all_table.heading(3,text='Date')
    all_table.heading(4,text='Quantity')
    all_table.heading(5,text='Sales Amount')
    for i in row:
        all_table.insert('','end',values=i)
    
    filter_label_1=Label(product_history_window,text='Filter Sales Report Productwise',font='20',bg='white').pack()
    filter_label_2=Label(product_history_window,text='Enter Product ID',font='20',bg='white').pack()
    filter_entry=Entry(product_history_window)
    filter_entry.pack()
    filter_button=Button(product_history_window,text='Filter',command=filter_product,bg='deepskyblue3',fg='white')
    filter_button.pack()
    filter_product_label=Label(product_history_window,text='Productwise Sales',bg='white').pack()
    filter_table=ttk.Treeview(product_history_window,columns=(1,2,3,4,5),show='headings',height='10')
    filter_table.pack()
    filter_table.heading(1,text='Customer ID')
    filter_table.heading(2,text='Book ID')
    filter_table.heading(3,text='Date')
    filter_table.heading(4,text='Quantity')
    filter_table.heading(5,text='Sales Amount')
    
    def gen_rep():
        generate_rep(filter_entry.get())
    
    button=Button(product_history_window,text='Generate Report',command=gen_rep,bg='deepskyblue3',fg='white').pack()
    def close_program():
        product_history_window.destroy()
    button_exit=Button(product_history_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        product_history_window.destroy()
        admin_activities()
    button_back=Button(product_history_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    product_history_window.mainloop()

    
    
    
# ----------------------------------------------------  Customerwise Sales Report  -----------------------------------------------

def sales_customerwise_rep():
    def filter_product():
        if(filter_entry.get()==''):
            MessageBox.showinfo('Filter Status','All fields are required')
        else:
            filter_table.delete(*filter_table.get_children())
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            cursor.execute("SELECT cust_id,b_id,date(cust_time),b_quantity,b_sales_amount FROM sales_details WHERE cust_id='"+ filter_entry.get() +"'")
            filter_row=cursor.fetchall()
            for i in filter_row:
                filter_table.insert('','end',values=i)
                
    def generate_rep(c_id):
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor=mydb.cursor()
        sql=f'select cust_id,b_id,date(cust_time),b_quantity,b_sales_amount where cust_id={c_id} into outfile "C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sales_report.csv" fields terminated by "," optionally enclosed by "" lines terminated by "\n" from sales_details;'
        cursor.execute(sql)
        cursor.execute('commit')
    
    
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor=mydb.cursor()
    sql='SELECT cust_id,b_id,date(cust_time),b_quantity,b_sales_amount FROM sales_details'
    cursor.execute(sql)
    row=cursor.fetchall()
    customer_history_window=Tk()
    customer_history_window.geometry('1000x850')
    customer_history_window.configure(bg='white')
    customer_history_window.title('Customerwise Sales Report')
    label_main=Label(customer_history_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    all_product_label=Label(customer_history_window,text='Customerwise Sales Report',bg='white').pack()
    all_table=ttk.Treeview(customer_history_window,columns=(1,2,3,4,5),show='headings',height='10')
    all_table.pack()
    all_table.heading(1,text='Customer ID')
    all_table.heading(2,text='Book ID')
    all_table.heading(3,text='Date')
    all_table.heading(4,text='Quantity')
    all_table.heading(5,text='Sales Amount')
    for i in row:
        all_table.insert('','end',values=i)
    
    filter_label_1=Label(customer_history_window,text='Filter Customers',font='20',bg='white').pack()
    filter_label_2=Label(customer_history_window,text='Enter Customer ID',font='20',bg='white').pack()
    filter_entry=Entry(customer_history_window)
    filter_entry.pack()
    filter_button=Button(customer_history_window,text='Filter',command=filter_product,bg='deepskyblue3',fg='white')
    filter_button.pack()
    filter_product_label=Label(customer_history_window,text='Filter Books Table',bg='white').pack()
    filter_table=ttk.Treeview(customer_history_window,columns=(1,2,3,4,5),show='headings',height='10')
    filter_table.pack()
    filter_table.heading(1,text='Customer ID')
    filter_table.heading(2,text='Book ID')
    filter_table.heading(3,text='Date')
    filter_table.heading(4,text='Quantity')
    filter_table.heading(5,text='Sales Amount')
    
    def gen_rep():
        generate_rep(filter_entry.get())
    
    button=Button(customer_history_window,text='Generate Report',command=gen_rep,bg='deepskyblue3',fg='white').pack()
    def close_program():
        customer_history_window.destroy()
    button_exit=Button(customer_history_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        customer_history_window.destroy()
        admin_activities()
    button_back=Button(customer_history_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    customer_history_window.mainloop()

    
    
    
    
    
# ----------------------------------------------------  See All Customers  -----------------------------------------------
def customer_report():
    def generate_rep():
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor=mydb.cursor()
        sql='select * into outfile "C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sales_report.csv" fields terminated by "," optionally enclosed by "" lines terminated by "\n" from cust_registration;'
        cursor.execute(sql)
        cursor.execute('commit')
        
    cust_window=Tk()
    cust_window.geometry('1000x850')
    cust_window.configure(bg='white')
    cust_window.title('Search Customer')
    label_main=Label(cust_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    all_customer_label=Label(cust_window,text='All Customers Table',bg='white').pack()
    all_cust_table=ttk.Treeview(cust_window,columns=(1,2,3,4,5,6),show='headings',height='10')
    all_cust_table.pack()
    all_cust_table.heading(1,text='Customer ID')
    all_cust_table.heading(2,text='First Name')
    all_cust_table.heading(3,text='Last Name')
    all_cust_table.heading(4,text='Email')
    all_cust_table.heading(5,text='Phone')
    all_cust_table.heading(6,text='Address')
    mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
    cursor=mydb.cursor()
    sql='SELECT * FROM cust_registration'
    cursor.execute(sql)
    all_cust_row=cursor.fetchall()
    for i in all_cust_row:
                all_cust_table.insert('','end',values=i)
    cursor.close()
    
    button=Button(cust_window,text='Generate Report',command=generate_rep,bg='deepskyblue3',fg='white').pack()
    def close_program():
        cust_window.destroy()
    button_exit=Button(cust_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        cust_window.destroy()
        admin_activities()
    button_back=Button(cust_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    cust_window.mainloop()
    
    
# ----------------------------------------------------  Stock Report  -----------------------------------------------
def stock_report():
    stock_window=Tk()
    stock_window.geometry('1000x850')
    stock_window.title('Stock Report')
    stock_window.configure(bg='white')
    label_main=Label(stock_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    
    def generate_rep(st,rep):
        mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
        cursor=mydb.cursor()
        sql=f'select {sp} into outfile "C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/{rep}.csv" fields terminated by "," optionally enclosed by "" lines terminated by "\n";'
        cursor.execute(sql)
        cursor.execute('commit')
    
    
    def choice_stock() :
        choice = choice_admin.get()
            
        if choice == 1 :
            rep='Purchased Stock'
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='select b_id,b_name,b_author,b_genre,b_cost,b_quantity,date(b_date) from purchased_list;'
            cursor.execute(sql)
            row=cursor.fetchall()
            stock_label=Label(stock_window,text='Filter Products Table',bg='white').pack()
            stock_table=ttk.Treeview(stock_window,columns=(1,2,3,4,5,6,7),show='headings',height='10')
            stock_table.pack()
            stock_table.heading(1,text='Book ID')
            stock_table.column(1,width=60,stretch=NO)
            stock_table.heading(2,text='Book Name')
            stock_table.column(2,width=140,stretch=NO)
            stock_table.heading(3,text='Author')
            stock_table.column(3,width=140,stretch=NO)
            stock_table.heading(4,text='Genre')
            stock_table.column(4,width=140,stretch=NO)
            stock_table.heading(5,text='Cost')
            stock_table.column(5,width=140,stretch=NO)
            stock_table.heading(6,text='Quantity')
            stock_table.column(6,width=140,stretch=NO)
            stock_table.heading(7,text='Date')
            stock_table.column(7,width=140,stretch=NO)
            for i in row:
                stock_table.insert('','end',values=i)
            
                
        elif choice == 2 :
            rep='Sold Stock'
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='select a.b_id,b.b_name,b.b_author,b.b_genre,b.b_cost,a.b_quantity,a.b_sales_amount,date(a.cust_time) from sales_details a join books_list b;'
            cursor.execute(sql)
            row=cursor.fetchall()
            stock_label=Label(stock_window,text='Filter Products Table',bg='white').pack()
            stock_table=ttk.Treeview(stock_window,columns=(1,2,3,4,5,6,7,8),show='headings',height='10')
            stock_table.pack()
            stock_table.heading(1,text='Book ID')
            stock_table.column(1,width=60,stretch=NO)
            stock_table.heading(2,text='Book Name')
            stock_table.column(2,width=140,stretch=NO)
            stock_table.heading(3,text='Author')
            stock_table.column(3,width=140,stretch=NO)
            stock_table.heading(4,text='Genre')
            stock_table.column(4,width=120,stretch=NO)
            stock_table.heading(5,text='Cost')
            stock_table.column(5,width=100,stretch=NO)
            stock_table.heading(6,text='Quantity')
            stock_table.column(6,width=120,stretch=NO)
            stock_table.heading(7,text='Sales Amt')
            stock_table.column(7,width=100,stretch=NO)
            stock_table.heading(8,text='Date')
            stock_table.column(8,width=140,stretch=NO)
            for i in row:
                stock_table.insert('','end',values=i)
            
        elif choice == 3 :
            rep='Available Stock'
            mydb=mysql.connect(host='localhost',user='root',password='entrepreneur@2991',database='book_store')
            cursor=mydb.cursor()
            sql='select b_id,b_name,b_author,b_genre,b_cost,b_quantity from books_list;'
            cursor.execute(sql)
            row=cursor.fetchall()
            stock_label=Label(stock_window,text='Filter Products Table',bg='white').pack()
            stock_table=ttk.Treeview(stock_window,columns=(1,2,3,4,5,6),show='headings',height='10')
            stock_table.pack()
            stock_table.heading(1,text='Book ID')
            stock_table.column(1,width=60,stretch=NO)
            stock_table.heading(2,text='Book Name')
            stock_table.column(2,width=180,stretch=NO)
            stock_table.heading(3,text='Author')
            stock_table.column(3,width=180,stretch=NO)
            stock_table.heading(4,text='Genre')
            stock_table.column(4,width=180,stretch=NO)
            stock_table.heading(5,text='Cost')
            stock_table.column(5,width=180,stretch=NO)
            stock_table.heading(6,text='Quantity')
            stock_table.column(6,width=180,stretch=NO)
            for i in row:
                stock_table.insert('','end',values=i)
        
        def gen_rep():
            generate_rep(sql,rep)                        
        button=Button(stock_window,text='Generate Report',command=gen_rep,bg='deepskyblue3',fg='white').pack()
    
    
    #radio_button 
    choice_admin = IntVar()
    search_label_1=Label(stock_window,text='Stock Report',font='20',bg='white').pack()
    radio_purchase    = Radiobutton(stock_window , text = 'Purchase Stock '   , value = 1 , variable = choice_admin,bg='white' ).pack()
    radio_sold = Radiobutton(stock_window , text = 'Stock Sold', value = 2 , variable = choice_admin,bg='white' ).pack()
    radio_available = Radiobutton(stock_window , text = 'Available Stock', value = 3 , variable = choice_admin,bg='white' ).pack()
    button_sel=Button(stock_window,text='Select',command=choice_stock,bg='deepskyblue3',fg='white').pack()
    
    def close_program():
        stock_window.destroy()
    button_exit=Button(stock_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
    def back_program():
        stock_window.destroy()
        admin_activities()
    button_back=Button(stock_window,text='BACK',bg='red',padx=80,font='comicsansns 10 bold',command=back_program).pack(side=BOTTOM)
    stock_window.mainloop()
    
    


# ----------------------------------------------------  Admin activities  -----------------------------------------------
def admin_activities():
    admin_window=Tk()
    admin_window.geometry('1000x850')
    admin_window.title('Welcome Admin')
    admin_window.configure(bg='white')
    
    def close_program():
        admin_window.destroy()
        
    def combine_funcs(*funcs):
        def combined_func(*args, **kwargs):
            for f in funcs:
                f(*args, **kwargs)
        return combined_func
        
    label_main=Label(admin_window,width=1000,text='Book Store Management System',bg='deepskyblue3',fg='white',font='40',padx=300,pady=10).pack()
    label_mode=Label(admin_window,text='Choose Operation ',font='comicsansns 15 bold',bg='white',fg='black',padx=20,pady=10).pack()
                                                       
                                                # Buttons for Shop Related Operations
    label_mode=Label(admin_window,text='Product Related Operations ',font='comicsansns 15 bold',bg='white',fg='black',padx=20,pady=20).pack()
    #frame1=Frame(admin_activities, bg='deepskyblue')
    button_new_pro=Button(admin_window,text='Add a new product',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,add_product)).pack()
    button_modify_pro=Button(admin_window,text='Update Product Details',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,update_product)).pack()
    #frame2=Frame(admin_activities, bg='deepskyblue')
    button_search_pro=Button(admin_window,text='Search  a Product',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,search_product)).pack()
    button_delete_pro=Button(admin_window,text='Delete a Product',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,delete_product)).pack()
    
                                                        #  Buttons for Customer Related Operations 
    label_mode_1=Label(admin_window,text='Customer Related Operations ',font='comicsansns 15 bold',bg='white',fg='black',padx=20,pady=10).pack()
    #frame3=Frame(admin_activities, bg='deepskyblue')
    button_registration_pro=Button(admin_window,text='Customer Registration',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,customer_registration)).pack()
    button_update_cust=Button(admin_window,text='Update Customer Details',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,update_customer)).pack()
    #frame4=Frame(admin_activities, bg='deepskyblue')
    button_search_cust=Button(admin_window,text='Search Customers',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,search_customer)).pack()
    button_del_cust=Button(admin_window,text='Delete Customer',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,delete_customer)).pack()
    button_buy_pro=Button(admin_window,text='Sell Products',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,sale_products)).pack()                        
                                
    label_mode_2=Label(admin_window,text='Reports',font='comicsansns 15 bold',bg='white',fg='black',padx=20,pady=20).pack()
    #frame5=Frame(admin_activities, bg='deepskyblue')    
    button_sales_history=Button(admin_window,text='Sales Report',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,sales_report)).pack()
    button_sales_prod_report=Button(admin_window,text='Productwise Sales Report',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,sales_productwise_rep)).pack()
    #frame6=Frame(admin_activities, bg='deepskyblue')    
    button_sales_cust_report=Button(admin_window,text='Customerwise Sales Report',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,sales_customerwise_rep)).pack()
    button_cust_report=Button(admin_window,text='Customer Details Report',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,customer_report)).pack()
    button_stock_report=Button(admin_window,text='Stock Details Report',padx=80,font='comicsansns 10 bold',bg='deepskyblue3',fg='white',command=combine_funcs(close_program,stock_report)).pack()
    
                                                            # Exit Button
    
    button_search_pro=Button(admin_window,text='EXIT',bg='red',padx=80,font='comicsansns 10 bold',command=close_program).pack(side=BOTTOM)
        
    admin_window.mainloop()
    
# --------------------------------------------------  Login Window  -----------------------------------------------------

def login():    
    login_window = Tk()
    login_window.geometry('1000x850')
    login_window.title('Admin Login')
    login_window.configure(bg='white')
    fontstyle = tkFont.Font(size=20)
    label_main=Label(login_window,width=1000,text='Welcome to The Book Store Management System!',bg='deepskyblue3',fg='white',font=fontstyle,padx=300,pady=50).pack()    
    # Logo
    logo = PhotoImage(file = 'bslogo.png')
    logo_label = Label(login_window , image = logo).pack()
        
    # username
    username = Label(login_window , text = 'Username * ',bg='white',fg='black',pady=10).pack()
    username_value = StringVar()
    username_text = Entry(login_window , textvariable = username_value).pack()
        
    # password
    password = Label(login_window , text = 'Password * ',bg='white',fg='black',pady=10).pack()
    password_value = StringVar()
    password_frame= Frame()
    password_text = Entry(login_window , textvariable = password_value).pack()
    
    
    def admin_login():
        user = username_value.get()
        password = password_value.get()
            
        if user == 'a' and password == 'a' :
            login_window.destroy()
            admin_activities()
                
        else :
            messagebox.showinfo('welcome' , 'welcome ' + user)
        
    # Login Button 
    login_button = Button(login_window , text = 'Login' , width = 25 , command = admin_login,bg='deepskyblue3').pack(pady=20)
        
    login_window.resizable(0,0)
    login_window.mainloop()
                                
login()
